# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart.csv")

# %%
# q1
df.shape
# Out:
# (303, 14)

# %%
# ابنجا با متد شیپ تعداد طر و طتون ها رو دیدیم

# %%
# q2
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %%
# با این متد اسم طتون ها رو و در اخر هم دیتا تایپ اون سطون ها رو به نشون میده

# %%
#q3
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# با توجه به متد و خروجی تایپ هر ستون گفته شده

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
#  ما در تسک شماره 4 با متد یونیک تعداد مقادیر یکتای هر ستون رو پیدا کردیم حالا میتونیم بگیم ستون هایی که عدد انها 2 است احتمال خیلی زیاد دودویی است و باتوجه به جدول هم ستون جنسیت فقط از 0 و یک تشکیل شده و همینطور بعدی
#  پس
#
#
# ---------------------------------------------------------------------------------------------------------------------------
# ستون هایی که 2 هستند معمولا دودویی هستند  ستون های
#
# sex         جنسیت زن -----> 0 ** مرد --------> 1
#
# fbs                 قند خون تاشتا   بله ----->1  ** خیر -------> 0
#
# exang           آنزین ناشی از ورزش 1 = بله ** 0 = خیر
#
# target                  وجود بیماری قلبی 1 = بله   *** 0 = خیر
#
# --------------------------------------------------------------------------------------------------------------------------
#
# ستون‌هایی که تعداد کم مقدار یکتا دارند و یعنی دسته‌ه هستند، دسته‌ای هستند
#
# cp              نوع درد قفسه سینه که احتمالا از 0 تا 3 درجه بندی شده
#
# restecg           نتیجه نوار قلب در حالت استراحت
#                      0 : طبیعی
#                      1 : ناهنجاری موج ST-T
#                      2 : هیپرتروفی بطن چپ
#
# slope               شیب قطعه ST در اوج ورزش
#                     0 : صعودی (Upsloping)
#                     1 : صاف (Flat)
#                     2 : نزولی (Downsloping)
#
#
# ca               تعداد رگ‌های اصلی رنگ‌آمیزی‌شده با فلوروسکوپی (0 تا 4)
#
#
# thal    نتیجه آزمایش تالاسمی (طبیعی، نقص ثابت، نقص برگشت‌پذیر)
#
#                     1 : طبیعی
#                     2 : نقص ثابت (Fixed Defect)
#                     3 : نقص برگشت‌پذیر (Reversible Defect)
#
#
# ---------------------------------------------------------------------------------------------------------------------
#
# بقیه ستون ها هم از نوع عددی هستند  چون تنوع زیادی دارند

# %% [markdown]
# Q 5

# %% [markdown]
#
#
#  age:       سن بیمار                         افزایش سن یکی از عوامل خطر بیماری قلبی است
#  sex :     جنسیت بیمار                           احتمال ابتلا در مردان و زنان متفاوت است
#  cp :       نوع درد قفسه سینه                    نوع درد می‌تواند نشانه بیماری قلبی باشد
#  trestbps:  فشار خون در حالت استراح          فشار خون بالا خطر بیماری‌های قلبی را افزایش می‌دهد
#  chol :     میزان کلسترول خون                            کلسترول بالا باعث گرفتگی عروق می‌شود
#  fbs :      قند خون ناشتا                         قند خون بالا با بیماری‌های قلبی مرتبط است
#  restecg  : نتیجه نوار قلب در حالت استراحت                  ناهنجاری‌های قلبی را نشان می‌دهد
#  thalach :  حداکثر ضربان قلب                        عملکرد قلب هنگام فعالیت را نشان می‌دهد
#
#  exang   :  آنژین ناشی از ورزش     وجود درد قفسه سینه هنگام ورزش می‌تواند نشانه بیماری قلبی باشد
#
#
#  oldpeak  : افت ST ناشی از ورزش                        شاخصی برای بررسی ایسکمی قلبی است
#  slope   : شیب قطعه ST                             در تشخیص بیماری عروق کرونر مؤثر است
#  ca  :      تعداد رگ‌های اصلی مشاهده‌شده             میزان درگیری عروق قلب را نشان می‌دهد
#  thal  :    نتیجه آزمایش تالاسمی                      نوع نقص در جریان خون قلب را مشخص می‌کند
#  target  :
#    وضعیت بیماری قلبی (0: سالم، 1: بیمار) متغیر هدف برای پیش‌بینی وجود بیماری قلبی است.

# %%
# 6

df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# متد isnull  خالی ها رو true بر میگردونه و پ ها رو false  و وقتی که ما جمع میزنیم 0 و یک ها با هم جمع میشوند پس با توجه به خروجی بالا با هیچ خالی نداریم

# %%
# 7

miss_data=df.isnull().sum()
miss_data / len(df) ** 100
# Out:
# age         0.0
# sex         0.0
# cp          0.0
# trestbps    0.0
# chol        0.0
# fbs         0.0
# restecg     0.0
# thalach     0.0
# exang       0.0
# oldpeak     0.0
# slope       0.0
# ca          0.0
# thal        0.0
# target      0.0
# dtype: float64

# %% [markdown]
# در اینجا چون ما داده نان نداریم همه صفر درصد هستند ولی این کد اینجوری کار میکنه که
#
# اول جمع داده های خالی رو بدست میاریم تقسیم بر لن دیتا فریم میکنیم که نسبت داده های خالی به کل داد ها را بفهمیم و بعد هم ضرب در 100 کردیم که به درصد بشه

# %%
#Q 8 & 9

repit_rows=df.duplicated()
repit_rows.sum()
# Out:
# np.int64(1)

# %% [markdown]
# با استفاده از این متد که تمام عناصر را با عناصر های بالا مقایسه میکنه و اگه همه عناصر ها با سطر های بالا با همون ترتیب برابر بود اون ستون را درست قرار میدهد الان چون یکسان نداریم همه را فالس داده و در نتیجه جمع فالس ها 0 میشود

# %%
df["target"].value_counts(normalize=True) * 100

sns.countplot(x="target" , data=df)

plt.title("target class")
plt.xlabel("target")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
target_counts=df["target"].value_counts()

plt.figure(figsize=(5,5))

plt.pie(
        target_counts,
        
        labels=target_counts.index ,
        
        autopct='%1.1f%%',
        startangle=180
        )

# %%
# Q11

target_percent = df['target'].value_counts(normalize=True) * 100
print(target_percent)
# Out:
# target
# 1    54.455446
# 0    45.544554
# Name: proportion, dtype: float64

# %%
# Q12

describe_data = df.describe()

describe_data
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Q 13


numerical_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

df[numerical_cols].mean().median()
# Out:
# np.float64(131.62376237623764)

# %%
# Q 14

# %%
# Q 15

# %%
# Q16

# import matplotlib.pyplot as plt

# plt.figure(figsize=(10,6))
# df[numerical_cols].boxplot()
# plt.title('Boxplot of Numerical Features')

# plt.show()

# %%
# 20

# %%
#26

name_table=["sex","cp","fbs","restecg","exang","slope","ca","thal"]

for i in name_table:
    print(f"moghayese:  {i}   v target")
    
    print(pd.crosstab(df[i],df["target"]))
# Out:
# moghayese:  sex   v target
# target    0   1
# sex
# 0        24  72
# 1       114  93
# moghayese:  cp   v target
# target    0   1
# cp
# 0       104  39
# 1         9  41
# 2        18  69
# 3         7  16
# moghayese:  fbs   v target
# target    0    1
# fbs
# 0       116  142
# 1        22   23
# moghayese:  restecg   v target
# target    0   1
# restecg
# 0        79  68
# 1        56  96
# 2         3   1
# moghayese:  exang   v target
# target   0    1
# exang
# 0       62  142
# 1       76   23
# moghayese:  slope   v target
# target   0    1
# slope
# 0       12    9
# 1       91   49
# 2       35  107
# moghayese:  ca   v target
# target   0    1
# ca
# 0       45  130
# 1       44   21
# 2       31    7
# 3       17    3
# 4        1    4
# moghayese:  thal   v target
# target   0    1
# thal
# 0        1    1
# 1       12    6
# 2       36  130
# 3       89   28

# %% [markdown]
# در این سوال میتوانیم به این پی ببریم که مقایسه کنیم ستونی رو‌با ستون دیگر
# برای مثال ما ستون جنسیت و ستون تارگت را مقایسه کردیم و برادش ما به این گونه بود
# بانوان عدم مبتلا به بیماری قلبی ۲۴ نفر و مبتلا به بیماری قلبی ۷۲ نفر هستند
# و اقایان عدم مبتلا ۱۱۴ نفر و مبتلا به بیماری قلبی ۹۳ نفر هستند
#
#
# cp
#
# در ستون بعدی که شدت درد بیمار را از عدد صفر تا سه نشان میدهد متوجه میشویم که بیمارهایی که درجه دردشان صفر بوده صد و چهار نفر عدم مبتلا و سی و نه نفر مبتلا به بیماری قلبی بوده بیمارانی که درجه دردشان یک بوده عدم مبتلا شن نُه ومبتلا چهل و یک نفر بوده بیماری‌های با درجه درد یک گرید دو هیجده نفر غیرمبتلا و شصت و نه در مبتلا بیماری‌های با درد قفس سینه با گرید سه هفت نفر غیرمبتلا و شونوزده
# نفر مبتلا بوده
#
#
# fbs
#
# ستون بعد قند خون ناشتا
# افراد عدم قند خون ناشتا ۱۴۲نفر مبتلا و ۱۱۶ نفر غیر مبتلا بوده
#
# افراد شامل قند خون ناشتا بوده اند
# ۲۲ نفر غیر مبتلا و ۲۳ نفر مبتلا بوده

# %%
#27

print("table zan ha va mard ha dar bimari")
pd.crosstab(df["sex"],df["target"],normalize="index") *100
# Out:
# table zan ha va mard ha dar bimari
# target          0          1
# sex
# 0       25.000000  75.000000
# 1       55.072464  44.927536

# %% [markdown]
# در اینجا به صورت جداگانه ستون جنسیت را با تارگت مقایسه کردیم و نرمالیز را روی ایندکس گزاشتیم تا نسبت به کل را بدهد و در اخر هم ضرب در ۱۰۰ کردیم تا درصد به ما بدهد
#
# بانوان مبتلا ۷۵ درصد و غیر مبتلا ۲۵ درصد هستند و
# اقایان هم افراد مبتلا ۴۴ درصد و غیر مبتلا ۵۵درصد است

# %%
#28

pd.crosstab(df["cp"],df["target"],normalize="index") *100
# Out:
# target          0          1
# cp
# 0       72.727273  27.272727
# 1       18.000000  82.000000
# 2       20.689655  79.310345
# 3       30.434783  69.565217

# %% [markdown]
# با توجه به ستون مبتلا ها عدد ۸۲ از همه بالا تر هست پس یعنی افراد با درد قفسه سینه گرید ۱بیشترین و بعد گرید ۲و بعد گرید ۳ و ۰

# %%
#29

pd.crosstab(df["exang"],df["target"])
# Out:
# target   0    1
# exang
# 0       62  142
# 1       76   23

# %% [markdown]
# با توجه به سوال که پرسیده شده ورزش در بیماری ارتباط دارد
#
# بله افرادی که ورزش میکنند و عدد انها ۱ هستند افراد مبتلاشون به شدت کمتر از افراد معمولی هستن نسبت ۱۴۲ به ۲۳

# %%
#30

hambastegi=df.corr()
hambastegi
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#31

plt.Figure(figsize=(12,9))

sns.heatmap(df.corr(),cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Q32
#
#
# در این تحلیل بسیار راحت میتوان فهمید که کدام یتون با کدام ستون رابطه مستقیم دارد
#
# طبق راهنمایی سمت راست تصویر ابی کمترین همبستگی و قهوه ای بیشترین همبستگی را دارد
# با توجه به سوال که که میپرسد تارگت با چی بیشترین ارتباط رو داره باید بگیم که تارگت با سی پی یا شدت درد بیمار بیشتر رو به قهوه ای است

# %% [markdown]
# #33
#
# ستون تارگت کمترین همبستگی را با ستون اولد پیک و اکسنج دارد

# %% [markdown]
# Q 34
#
# با توجه به نمودار هیت مپ بالا
# ویژگی های
#
# slope == thalach
#
# target== cp
#
# Target == thalach

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df , x="age" , y= "chol" , hue="target")
plt.title("age v colesterol")
# Out:
# Text(0.5, 1.0, 'age v colesterol')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df , x="age" , y= "thalach" , hue="target")
plt.title("age v salamati ghalb")
# Out:
# Text(0.5, 1.0, 'age v colesterol')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df , x="chol" , y= "trestbps" , hue="target")
plt.title("colestrol v feshar khon sabet ")
# Out:
# Text(0.5, 1.0, 'colestrol v feshar khon sabet ')

# %% [markdown]
# نوضیحی ندارم

# %%
#Q36

list_rows=["age","thalach","oldpeak","chol","target"]

sns.pairplot(df[list_rows],hue="target",diag_kind="hist")

# %% [markdown]
# توضیح خاصی ندارم
#
# فقط میدونم مقایسه مثلا سن و کلسترون

# %%
#Q37
target_0= df [df["target"] == 0]
target_1 = df[df["target"] == 1]

print("target 0 = ", target_0.mean())
print ("target 1 =" , target_1.mean())
# Out:
# target 0 =  <bound method DataFrame.mean of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 165   67    1   0       160   286    0        0      108      1      1.5
# 166   67    1   0       120   229    0        0      129      1      2.6
# 167   62    0   0       140   268    0        0      160      0      3.6
# 168   63    1   0       130   254    0        0      147      0      1.4
# 169   53    1   0       140   203    1        0      155      1      3.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %% [markdown]
# در اینجا ما دو متغیر به اسم تارگت صفر و تارگت یک درست کردیم در تارگت صفر از ستون تارگت ها تارگت هایی که صفر بودند رو ریختیم و در تارگت یک تارگت هایی که مساوی با یک بودند را ریختیم در پایین میانگین هر دو را پرینت گرفتیم

# %%
#38

df.groupby(["sex", "target"]).mean()
# Out:
#                   age        cp    trestbps        chol       fbs   restecg  \
# sex target
# 0   0       59.041667  0.166667  146.125000  274.958333  0.250000  0.541667
#     1       54.555556  1.333333  128.736111  256.750000  0.083333  0.583333
# 1   0       56.087719  0.543860  131.929825  246.061404  0.140351  0.429825
#     1       50.903226  1.408602  129.741935  230.989247  0.182796  0.602151
#
#                thalach     exang   oldpeak     slope        ca      thal
# sex target
# 0   0       142.416667  0.583333  1.841667  0.958333  1.291667  2.500000
#     1       154.027778  0.111111  0.554167  1.583333  0.305556  2.000000
# 1   0       138.403509  0.543860  1.531579  1.210526  1.140351  2.552632
#     1       161.903226  0.161290  0.605376  1.602151  0.408602  2.215054

# %% [markdown]
# میانگین قوانستیم برای مثال جنسیت صفر که خانم است دو تارگت صفر و یک دارند و هر یک از اینها میانگین هر ستون را نمایش داده برای مثال خانم ها افراد مبتلا سن پنجاه و چهار سال میانگین گرید درد قلب یک ممیزهسی و سه کلسترون دویست و پنجاه و شیش و همچنین افراد غیرمبتلا میانگین سنی پنجاه و نه سال میانگین درد صفر ممیزه شونزده صدم کلسترون دویست و هفتاد و چهار و همچنین در مردان  افراد غیرمبتلا پنجاه و شیش سال افراد مبتلا پنجاه سال

# %%
#39


df.groupby(["cp", "target"]).mean()
# Out:
#                  age       sex    trestbps        chol       fbs   restecg  \
# cp target
# 0  0       56.298077  0.798077  133.692308  251.932692  0.163462  0.442308
#    1       54.076923  0.538462  127.564103  245.333333  0.025641  0.564103
# 1  0       57.444444  0.777778  138.444444  263.444444  0.111111  0.333333
#    1       50.024390  0.609756  126.195122  240.682927  0.097561  0.682927
# 2  0       58.500000  0.944444  135.055556  239.000000  0.166667  0.500000
#    1       52.217391  0.507246  129.159420  244.260870  0.202899  0.623188
# 3  0       55.142857  1.000000  138.000000  253.714286  0.142857  0.571429
#    1       56.187500  0.750000  142.125000  229.875000  0.250000  0.312500
#
#               thalach     exang   oldpeak     slope        ca      thal
# cp target
# 0  0       136.057692  0.673077  1.683654  1.134615  1.240385  2.576923
#    1       152.487179  0.256410  0.582051  1.589744  0.230769  2.102564
# ...

# %% [markdown]
# در درجه بندی افراد با درد صفر افراد مبتلا میانگین سنی پنجاه و چهار سال افراد غیرمبتلا میانگین سنی پنجاه و شش سال در درجه درد یک افراد مبتلا با میانگین سنی پنجاه سال میانگین سنی غیرمبتلا پنجاه و هفت سال افراد با درجه درد قوس سینه دو افراد مبتلا میانگین سنی پنجاه و دو سال میانگین سنی افرادافراد غیرمبتلا پنجاه و هشت سال افراد باداشتن درجه درد سه میانگین سنی افراد مبتلا پنجاه و شش سال میانگین سنی افراد غیرمبتلا پنجاه و پنج سال
